# %%
import pandas as pd
import pymysql.cursors
import matplotlib.pyplot as plt

# %%
import pymysql
from sqlalchemy import create_engine
# Open database connection
# conn = pymysql.connect(host='127.0.0.1', port=3306, user='testadmin', passwd='testadmin', db='test', charset='utf8')
conn  =create_engine('mysql+pymysql://testadmin:testadmin@localhost:3306/test?charset=utf8mb4')
data_query = "SELECT * FROM all_event"
category_query = "SELECT * FROM category_type"
data_df = pd.read_sql(data_query, conn)
category_df = pd.read_sql(category_query, conn)

# %%
## join 類別跟事件

data_df['category'] = data_df['category'].astype(int)
category_df['id'] = category_df['id'].astype(int)

category_df.rename(columns = {"value":"category"})

merge_df =pd.merge(data_df, category_df, left_on="category", right_on="id")

display(merge_df)
# Out:
#                      time             location      locationName onSales  \
# 0     2021/10/19 09:00:00  臺中市40453 臺中市北區館前路一號           人類文化廳二樓       Y
# 1     2019/03/05 09:00:00           臺中市北區館前路1號         國立自然科學博物館       Y
# 2     2020/01/05 00:00:00             花蓮市文復路6號    花蓮縣石雕博物館二樓常設展區       Y
# 3     2021/01/01 09:00:00       嘉義縣太保市故宮大道888號       國立故宮博物院南部院區       Y
# 4     2021/01/01 09:00:00               宜蘭縣蘇澳鎮         蘇澳鎮（宜蘭縣）=       N
# ...                   ...                  ...               ...     ...
# 9124  2021/11/20 14:00:00               無無線上觀賞              線上觀賞       Y
# 9125  2021/11/20 20:00:00               無無線上觀賞              線上觀賞       Y
# 9126  2021/11/21 14:00:00               無無線上觀賞              線上觀賞       Y
# 9127  2021/11/21 20:00:00               無無線上觀賞              線上觀賞       Y
# 9128  2021/10/30 00:00:00                       永豐 Legacy Taipei       Y
#
#                                                   price    latitude  \
# 0                                         全票100元，半票70元。   24.157234
# 1                                                        24.1572555
# 2     全票20元、半票10元(20人以上團體、學生、軍警)\r\n花蓮縣民、身心障礙及陪同者1人、...  23.9899822
# 3                                                全票+150  23.4704066
# 4                                                              None
# ...                                                 ...         ...
# 9124                                                     24.8252393
# 9125                                                     24.8252393
# 9126                                                     24.8252393
# 9127                                                     24.8252393
# 9128                                                           None
#
#         longitude              endTime version                       UID  \
# 0       120.66606  2028/12/31 17:00:00     1.4  5b3dd544aaa378d7ca9a2e9a
# 1     120.6661841  2024/03/05 17:00:00     1.4  5c7e1bcdaaa375d860933d3a
# 2     121.6287389  2021/12/31 00:00:00     1.4  5e086b80d083a37cd8cacfdc
# 3     120.2913281  2021/12/26 17:00:00     1.4  5e1627d6d083a37cd8cad3dd
# 4            None  2021/12/31 17:00:00     1.4  5e5ffbf8d083a329401eed57
# ...           ...                  ...     ...                       ...
# 9124  121.1806029  2021/11/23 14:00:00     1.4  616b0591d083a38f6c36c7d5
# 9125  121.1806029  2021/11/23 20:00:00     1.4  616b0591d083a38f6c36c7d5
# 9126  121.1806029  2021/11/24 14:00:00     1.4  616b0591d083a38f6c36c7d5
# 9127  121.1806029  2021/11/24 20:00:00     1.4  616b0591d083a38f6c36c7d5
# 9128         None  2021/10/30 00:00:00     1.4  616b2fb8d083a38f6c36c7e8
#
#                                            title  category discountInfo  \
# 0                    科博館《古代人說故事》南屯山仔腳遺址出土的鐵刀首亮相!         6
# 1                   曾侯乙編鐘「重返」科博館  小編鐘與VR相伴共推科學教育         6
# 2                                  繆斯的雕刻刀─典藏石雕特展         6
# 3                                       皇帝的多寶格特展         6
# 4                                  漁村生活體驗活動－一線成網         6
# ...                                          ...       ...          ...
# 9124  【OPENTIX Live】虛擬實境互動劇場Online--脫逃吧! 人類! 2.0         5
# 9125  【OPENTIX Live】虛擬實境互動劇場Online--脫逃吧! 人類! 2.0         5
# 9126  【OPENTIX Live】虛擬實境互動劇場Online--脫逃吧! 人類! 2.0         5
# 9127  【OPENTIX Live】虛擬實境互動劇場Online--脫逃吧! 人類! 2.0         5
# 9128                             魏嘉瑩 你好嗎 新專同名演唱會         5
#
#          masterUnit comment   startDate     endDate  hitRate  id value
# 0     ['國立自然科學博物館']          2021/10/19  2028/12/31     1724   6    展覽
# 1     ['國立自然科學博物館']          2019/03/05  2024/03/05     1771   6    展覽
# 2                []          2020/01/05  2021/12/31    35006   6    展覽
# 3       ['國立故宮博物院']          2021/01/01  2021/12/26     1362   6    展覽
# 4     ['宜蘭縣立蘭陽博物館']          2021/01/01  2021/12/31      714   6    展覽
# ...             ...     ...         ...         ...      ...  ..   ...
# 9124             []          2021/11/14  2021/11/24        0   5  獨立音樂
# 9125             []          2021/11/14  2021/11/24        0   5  獨立音樂
# 9126             []          2021/11/14  2021/11/24        0   5  獨立音樂
# 9127             []          2021/11/14  2021/11/24        0   5  獨立音樂
# 9128             []          2021/10/30  2021/10/30        0   5  獨立音樂
#
# [9129 rows x 20 columns]

# %%
##
count_df = merge_df.groupby(by=['value']).size().reset_index(name ='acivity amount')

count_df.rename(columns = {"value":"category"})

display(count_df)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_3432/1849593637.py in <module>
#       1 ##
# ----> 2 count_df = merge_df.groupby(by=['category_name']).size().reset_index(name ='acivity amount')
#       3
#       4 count_df.rename(columns = {"value":"category"})
#       5
#
# ~\.conda\envs\python_test\lib\site-packages\pandas\core\frame.py in groupby(self, by, axis, level, as_index, sort, group_keys, squeeze, observed, dropna)
#    7629         # error: Argument "squeeze" to "DataFrameGroupBy" has incompatible type
#    7630         # "Union[bool, NoDefault]"; expected "bool"
# -> 7631         return DataFrameGroupBy(
#    7632             obj=self,
#    7633             keys=by,
#
# ~\.conda\envs\python_test\lib\site-packages\pandas\core\groupby\groupby.py in __init__(self, obj, keys, axis, level, grouper, exclusions, selection, as_index, sort, group_keys, squeeze, observed, mutated, dropna)
#     887             from pandas.core.groupby.grouper import get_grouper
#     888
# --> 889             grouper, exclusions, obj = get_grouper(
#     890                 obj,
#     891                 keys,
#
# ~\.conda\envs\python_test\lib\site-packages\pandas\core\groupby\grouper.py in get_grouper(obj, key, axis, level, sort, observed, mutated, validate, dropna)
#     860                 in_axis, level, gpr = False, gpr, None
#     861             else:
# --> 862                 raise KeyError(gpr)
#     863         elif isinstance(gpr, Grouper) and gpr.key is not None:
#     864             # Add key to exclusions
#
# KeyError: 'category_name'
