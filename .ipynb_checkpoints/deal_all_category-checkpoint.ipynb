# %%
import pandas as pd
import json

# %%
## 從rest api 的方向抓
## https://cloud.culture.tw/frontsite/trans/SearchShowAction.do?method=doFindTypeJ&category=all
## 以category all 做選擇 拉取所有活動

local_path ="C:/Users/USER/Desktop/python_work"


    
df = pd.read_json(local_path + "/" + "all_category.json")



df.replace('^\s+', '', regex=True, inplace=True) #front
df.replace('\s+$', '', regex=True, inplace=True) #end
show_df= df[['version', 'UID','title','category','discountInfo','masterUnit','comment','startDate','endDate','hitRate']]
df['masterUnit'] = df['masterUnit'].astype(str)
display(show_df)
# Out:
#       version                       UID                         title  \
# 0         1.4  5aa90765c6355e63fc0cf750           週末蚊子電影院-Cars 2：世界大賽
# 1         1.4  5b3dd544aaa378d7ca9a2e9a   科博館《古代人說故事》南屯山仔腳遺址出土的鐵刀首亮相!
# 2         1.4  5b3dd544aaa378d7ca9a2e9a   科博館《古代人說故事》南屯山仔腳遺址出土的鐵刀首亮相!
# 3         1.4  5c7e1bcdaaa375d860933d3a  曾侯乙編鐘「重返」科博館  小編鐘與VR相伴共推科學教育
# 4         1.4  5c7e1bcdaaa375d860933d3a  曾侯乙編鐘「重返」科博館  小編鐘與VR相伴共推科學教育
# ...       ...                       ...                           ...
# 3674      1.4  616c747cd083a38f6c36c801                   老屋。花園 巡迴演唱會
# 3675      1.4  616c747cd083a38f6c36c802                   老屋。花園 巡迴演唱會
# 3676      1.4  616d191eaaa3465eb167c948         teamLab未來遊樂園&與花共生的動物們
# 3677      1.4  616d1bb6aaa3465eb167c949                     2021鶯歌藝術季
# 3678      1.4  616d1bb6aaa3465eb167c949                     2021鶯歌藝術季
#
#       category discountInfo                           masterUnit comment  \
# 0           16                                                []
# 1            6                                       [國立自然科學博物館]
# 2            4                                       [國立自然科學博物館]
# 3            6                                       [國立自然科學博物館]
# 4            4                                       [國立自然科學博物館]
# ...        ...          ...                                  ...     ...
# 3674         1                                           [山狗大樂團]
# 3675         1                                           [山狗大樂團]
# 3676         6                           [teamLab Kids 、 聯合數位文創]
# 3677         6               [新北市政府、新北市政府文化局、新北市立鶯歌陶瓷博物館、新北市美術館]
# 3678         4               [新北市政府、新北市政府文化局、新北市立鶯歌陶瓷博物館、新北市美術館]
#
#        startDate     endDate  hitRate
# 0     2112/01/29  2112/01/29        0
# 1     2021/10/19  2028/12/31     1724
# 2     2021/10/19  2028/12/31     1724
# 3     2019/03/05  2024/03/05     1771
# 4     2019/03/05  2024/03/05     1771
# ...          ...         ...      ...
# 3674  2021/10/30  2021/10/30        0
# 3675  2021/10/31  2021/10/31        0
# 3676  2021/10/08  2022/02/28        0
# 3677  2021/10/09  2021/12/26        0
# 3678  2021/10/09  2021/12/26        0
#
# [3679 rows x 10 columns]

# %%
import pymysql
from sqlalchemy import create_engine
# Open database connection
# conn = pymysql.connect(host='127.0.0.1', port=3306, user='testadmin', passwd='testadmin', db='test', charset='utf8')
conn  =create_engine('mysql+pymysql://testadmin:testadmin@localhost:3306/test?charset=utf8mb4')


show_df.to_sql(name='all_category', con=conn, if_exists = 'replace', index=False)
# Out:
# ---------------------------------------------------------------------------
# ProgrammingError                          Traceback (most recent call last)
# ~\.conda\envs\python_test\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1750                 if not evt_handled:
# -> 1751                     self.dialect.do_executemany(
#    1752                         cursor, statement, parameters, context
#
# ~\.conda\envs\python_test\lib\site-packages\sqlalchemy\dialects\mysql\mysqldb.py in do_executemany(self, cursor, statement, parameters, context)
#     196     def do_executemany(self, cursor, statement, parameters, context=None):
# --> 197         rowcount = cursor.executemany(statement, parameters)
#     198         if context is not None:
#
# ~\.conda\envs\python_test\lib\site-packages\pymysql\cursors.py in executemany(self, query, args)
#     172             assert q_values[0] == "(" and q_values[-1] == ")"
# --> 173             return self._do_execute_many(
#     174                 q_prefix,
#
# ~\.conda\envs\python_test\lib\site-packages\pymysql\cursors.py in _do_execute_many(self, prefix, values, postfix, args, max_stmt_length, encoding)
#     210             sql += v
# --> 211         rows += self.execute(sql + postfix)
#     212         self.rowcount = rows
#
# ~\.conda\envs\python_test\lib\site-packages\pymysql\cursors.py in execute(self, query, args)
#     147
# --> 148         result = self._query(query)
#     149         self._executed = query
#
# ~\.conda\envs\python_test\lib\site-packages\pymysql\cursors.py in _query(self, q)
#     309         self._clear_result()
# --> 310         conn.query(q)
#     311         self._do_get_result()
#
# ~\.conda\envs\python_test\lib\site-packages\pymysql\connections.py in query(self, sql, unbuffered)
#     547         self._execute_command(COMMAND.COM_QUERY, sql)
# --> 548         self._affected_rows = self._read_query_result(unbuffered=unbuffered)
#     549         return self._affected_rows
#
# ~\.conda\envs\python_test\lib\site-packages\pymysql\connections.py in _read_query_result(self, unbuffered)
#     774             result = MySQLResult(self)
# --> 775             result.read()
#     776         self._result = result
#
# ~\.conda\envs\python_test\lib\site-packages\pymysql\connections.py in read(self)
#    1155         try:
# -> 1156             first_packet = self.connection._read_packet()
#    1157
#
# ~\.conda\envs\python_test\lib\site-packages\pymysql\connections.py in _read_packet(self, packet_type)
#     724                 self._result.unbuffered_active = False
# --> 725             packet.raise_for_error()
#     726         return packet
#
# ~\.conda\envs\python_test\lib\site-packages\pymysql\protocol.py in raise_for_error(self)
#     220             print("errno =", errno)
# --> 221         err.raise_mysql_exception(self._data)
#     222
#
# ~\.conda\envs\python_test\lib\site-packages\pymysql\err.py in raise_mysql_exception(data)
#     142         errorclass = InternalError if errno < 1000 else OperationalError
# --> 143     raise errorclass(errno, errval)
#
# ProgrammingError: (1064, "You have an error in your SQL syntax; check the manual that corresponds to your MySQL server version for the right syntax to use near '), '', '2112/01/29', '2112/01/29', 0),(1.4e0, '5b3dd544aaa378d7ca9a2e9a', '科å\x8d' at line 1")
#
# The above exception was the direct cause of the following exception:
#
# ProgrammingError                          Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_20352/2798710067.py in <module>
#       6
#       7
# ----> 8 show_df.to_sql(name='all_category', con=conn, if_exists = 'replace', index=False)
#       9
#
# ~\.conda\envs\python_test\lib\site-packages\pandas\core\generic.py in to_sql(self, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#    2870         from pandas.io import sql
#    2871
# -> 2872         sql.to_sql(
#    2873             self,
#    2874             name,
#
# ~\.conda\envs\python_test\lib\site-packages\pandas\io\sql.py in to_sql(frame, name, con, schema, if_exists, index, index_label, chunksize, dtype, method, engine, **engine_kwargs)
#     715         )
#     716
# --> 717     pandas_sql.to_sql(
#     718         frame,
#     719         name,
#
# ~\.conda\envs\python_test\lib\site-packages\pandas\io\sql.py in to_sql(self, frame, name, if_exists, index, index_label, schema, chunksize, dtype, method, engine, **engine_kwargs)
#    1759         )
#    1760
# -> 1761         sql_engine.insert_records(
#    1762             table=table,
#    1763             con=self.connectable,
#
# ~\.conda\envs\python_test\lib\site-packages\pandas\io\sql.py in insert_records(self, table, con, frame, name, index, schema, chunksize, method, **engine_kwargs)
#    1348                 raise ValueError("inf cannot be used with MySQL") from err
#    1349             else:
# -> 1350                 raise err
#    1351
#    1352
#
# ~\.conda\envs\python_test\lib\site-packages\pandas\io\sql.py in insert_records(self, table, con, frame, name, index, schema, chunksize, method, **engine_kwargs)
#    1338
#    1339         try:
# -> 1340             table.insert(chunksize=chunksize, method=method)
#    1341         except exc.SQLAlchemyError as err:
#    1342             # GH34431
#
# ~\.conda\envs\python_test\lib\site-packages\pandas\io\sql.py in insert(self, chunksize, method)
#     965
#     966                 chunk_iter = zip(*[arr[start_i:end_i] for arr in data_list])
# --> 967                 exec_insert(conn, keys, chunk_iter)
#     968
#     969     def _query_iterator(
#
# ~\.conda\envs\python_test\lib\site-packages\pandas\io\sql.py in _execute_insert(self, conn, keys, data_iter)
#     880         """
#     881         data = [dict(zip(keys, row)) for row in data_iter]
# --> 882         conn.execute(self.table.insert(), data)
#     883
#     884     def _execute_insert_multi(self, conn, keys: list[str], data_iter):
#
# ~\.conda\envs\python_test\lib\site-packages\sqlalchemy\engine\base.py in execute(self, statement, *multiparams, **params)
#    1261             )
#    1262         else:
# -> 1263             return meth(self, multiparams, params, _EMPTY_EXECUTION_OPTS)
#    1264
#    1265     def _execute_function(self, func, multiparams, params, execution_options):
#
# ~\.conda\envs\python_test\lib\site-packages\sqlalchemy\sql\elements.py in _execute_on_connection(self, connection, multiparams, params, execution_options, _force)
#     321     ):
#     322         if _force or self.supports_execution:
# --> 323             return connection._execute_clauseelement(
#     324                 self, multiparams, params, execution_options
#     325             )
#
# ~\.conda\envs\python_test\lib\site-packages\sqlalchemy\engine\base.py in _execute_clauseelement(self, elem, multiparams, params, execution_options)
#    1450             linting=self.dialect.compiler_linting | compiler.WARN_LINTING,
#    1451         )
# -> 1452         ret = self._execute_context(
#    1453             dialect,
#    1454             dialect.execution_ctx_cls._init_compiled,
#
# ~\.conda\envs\python_test\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1812
#    1813         except BaseException as e:
# -> 1814             self._handle_dbapi_exception(
#    1815                 e, statement, parameters, cursor, context
#    1816             )
#
# ~\.conda\envs\python_test\lib\site-packages\sqlalchemy\engine\base.py in _handle_dbapi_exception(self, e, statement, parameters, cursor, context)
#    1993                 util.raise_(newraise, with_traceback=exc_info[2], from_=e)
#    1994             elif should_wrap:
# -> 1995                 util.raise_(
#    1996                     sqlalchemy_exception, with_traceback=exc_info[2], from_=e
#    1997                 )
#
# ~\.conda\envs\python_test\lib\site-packages\sqlalchemy\util\compat.py in raise_(***failed resolving arguments***)
#     205
#     206         try:
# --> 207             raise exception
#     208         finally:
#     209             # credit to
#
# ~\.conda\envs\python_test\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1749                             break
#    1750                 if not evt_handled:
# -> 1751                     self.dialect.do_executemany(
#    1752                         cursor, statement, parameters, context
#    1753                     )
#
# ~\.conda\envs\python_test\lib\site-packages\sqlalchemy\dialects\mysql\mysqldb.py in do_executemany(self, cursor, statement, parameters, context)
#     195
#     196     def do_executemany(self, cursor, statement, parameters, context=None):
# --> 197         rowcount = cursor.executemany(statement, parameters)
#     198         if context is not None:
#     199             context._rowcount = rowcount
#
# ~\.conda\envs\python_test\lib\site-packages\pymysql\cursors.py in executemany(self, query, args)
#     171             q_postfix = m.group(3) or ""
#     172             assert q_values[0] == "(" and q_values[-1] == ")"
# --> 173             return self._do_execute_many(
#     174                 q_prefix,
#     175                 q_values,
#
# ~\.conda\envs\python_test\lib\site-packages\pymysql\cursors.py in _do_execute_many(self, prefix, values, postfix, args, max_stmt_length, encoding)
#     209                 sql += b","
#     210             sql += v
# --> 211         rows += self.execute(sql + postfix)
#     212         self.rowcount = rows
#     213         return rows
#
# ~\.conda\envs\python_test\lib\site-packages\pymysql\cursors.py in execute(self, query, args)
#     146         query = self.mogrify(query, args)
#     147
# --> 148         result = self._query(query)
#     149         self._executed = query
#     150         return result
#
# ~\.conda\envs\python_test\lib\site-packages\pymysql\cursors.py in _query(self, q)
#     308         self._last_executed = q
#     309         self._clear_result()
# --> 310         conn.query(q)
#     311         self._do_get_result()
#     312         return self.rowcount
#
# ~\.conda\envs\python_test\lib\site-packages\pymysql\connections.py in query(self, sql, unbuffered)
#     546             sql = sql.encode(self.encoding, "surrogateescape")
#     547         self._execute_command(COMMAND.COM_QUERY, sql)
# --> 548         self._affected_rows = self._read_query_result(unbuffered=unbuffered)
#     549         return self._affected_rows
#     550
#
# ~\.conda\envs\python_test\lib\site-packages\pymysql\connections.py in _read_query_result(self, unbuffered)
#     773         else:
#     774             result = MySQLResult(self)
# --> 775             result.read()
#     776         self._result = result
#     777         if result.server_status is not None:
#
# ~\.conda\envs\python_test\lib\site-packages\pymysql\connections.py in read(self)
#    1154     def read(self):
#    1155         try:
# -> 1156             first_packet = self.connection._read_packet()
#    1157
#    1158             if first_packet.is_ok_packet():
#
# ~\.conda\envs\python_test\lib\site-packages\pymysql\connections.py in _read_packet(self, packet_type)
#     723             if self._result is not None and self._result.unbuffered_active is True:
#     724                 self._result.unbuffered_active = False
# --> 725             packet.raise_for_error()
#     726         return packet
#     727
#
# ~\.conda\envs\python_test\lib\site-packages\pymysql\protocol.py in raise_for_error(self)
#     219         if DEBUG:
#     220             print("errno =", errno)
# --> 221         err.raise_mysql_exception(self._data)
#     222
#     223     def dump(self):
#
# ~\.conda\envs\python_test\lib\site-packages\pymysql\err.py in raise_mysql_exception(data)
#     141     if errorclass is None:
#     142         errorclass = InternalError if errno < 1000 else OperationalError
# --> 143     raise errorclass(errno, errval)
#
# ProgrammingError: (pymysql.err.ProgrammingError) (1064, "You have an error in your SQL syntax; check the manual that corresponds to your MySQL server version for the right syntax to use near '), '', '2112/01/29', '2112/01/29', 0),(1.4e0, '5b3dd544aaa378d7ca9a2e9a', '科å\x8d' at line 1")
# [SQL: INSERT INTO all_category (version, `UID`, title, category, `discountInfo`, `masterUnit`, comment, `startDate`, `endDate`, `hitRate`) VALUES (%(version)s, %(UID)s, %(title)s, %(category)s, %(discountInfo)s, %(masterUnit)s, %(comment)s, %(startDate)s, %(endDate)s, %(hitRate)s)]
# [parameters: ({'version': 1.4, 'UID': '5aa90765c6355e63fc0cf750', 'title': '週末蚊子電影院-Cars 2：世界大賽', 'category': 16, 'discountInfo': '', 'masterUnit': [], 'comment': '', 'startDate': '2112/01/29', 'endDate': '2112/01/29', 'hitRate': 0}, {'version': 1.4, 'UID': '5b3dd544aaa378d7ca9a2e9a', 'title': '科博館《古代人說故事》南屯山仔腳遺址出土的鐵刀首亮相!', 'category': 6, 'discountInfo': '', 'masterUnit': ['國立自然科學博物館'], 'comment': '', 'startDate': '2021/10/19', 'endDate': '2028/12/31', 'hitRate': 1724}, {'version': 1.4, 'UID': '5b3dd544aaa378d7ca9a2e9a', 'title': '科博館《古代人說故事》南屯山仔腳遺址出土的鐵刀首亮相!', 'category': 4, 'discountInfo': '', 'masterUnit': ['國立自然科學博物館'], 'comment': '', 'startDate': '2021/10/19', 'endDate': '2028/12/31', 'hitRate': 1724}, {'version': 1.4, 'UID': '5c7e1bcdaaa375d860933d3a', 'title': '曾侯乙編鐘「重返」科博館  小編鐘與VR相伴共推科學教育', 'category': 6, 'discountInfo': '', 'masterUnit': ['國立自然科學博物館'], 'comment': '', 'startDate': '2019/03/05', 'endDate': '2024/03/05', 'hitRate': 1771}, {'version': 1.4, 'UID': '5c7e1bcdaaa375d860933d3a', 'title': '曾侯乙編鐘「重返」科博館  小編鐘與VR相伴共推科學教育', 'category': 4, 'discountInfo': '', 'masterUnit': ['國立自然科學博物館'], 'comment': '', 'startDate': '2019/03/05', 'endDate': '2024/03/05', 'hitRate': 1771}, {'version': 1.4, 'UID': '5c9a1560d083a30290d1b36f', 'title': '傳藝工坊－工藝師駐園資訊', 'category': 3, 'discountInfo': '', 'masterUnit': ['國立傳統藝術中心'], 'comment': '', 'startDate': '2021/02/15', 'endDate': '2021/12/15', 'hitRate': 1655}, {'version': 1.4, 'UID': '5cd25532aaa3f054c2cc6bad', 'title': '魔幻琺瑯/七宝烧體驗課程', 'category': 19, 'discountInfo': '不預收費用，上課繳費', 'masterUnit': ['築好玩藝'], 'comment': '因空間有限，怕線上報名超額超收，※限額課程在收到您的報名資料後無論有沒有在限額內築好玩藝一定會再一天內發Mail與您聯絡（若一天內沒收到mail請查一下您信箱垃圾桶），※限額課程若報名在名額外才會專人電話通知....築好玩藝團隊歡迎您.....感謝！！', 'startDate': '2021/10/23', 'endDate': '2029/12/30', 'hitRate': 1889}, {'version': 1.4, 'UID': '5cd25532aaa3f054c2cc6bad', 'title': '魔幻琺瑯/七宝烧體驗課程', 'category': 4, 'discountInfo': '不預收費用，上課繳費', 'masterUnit': ['築好玩藝'], 'comment': '因空間有限，怕線上報名超額超收，※限額課程在收到您的報名資料後無論有沒有在限額內築好玩藝一定會再一天內發Mail與您聯絡（若一天內沒收到mail請查一下您信箱垃圾桶），※限額課程若報名在名額外才會專人電話通知....築好玩藝團隊歡迎您.....感謝！！', 'startDate': '2021/10/23', 'endDate': '2029/12/30', 'hitRate': 1889}  ... displaying 10 of 3679 total bound parameter sets ...  {'version': 1.4, 'UID': '616d1bb6aaa3465eb167c949', 'title': '2021鶯歌藝術季', 'category': 6, 'discountInfo': '', 'masterUnit': ['新北市政府、新北市政府文化局、新北市立鶯歌陶瓷博物館、新北市美術館'], 'comment': '', 'startDate': '2021/10/09', 'endDate': '2021/12/26', 'hitRate': 0}, {'version': 1.4, 'UID': '616d1bb6aaa3465eb167c949', 'title': '2021鶯歌藝術季', 'category': 4, 'discountInfo': '', 'masterUnit': ['新北市政府、新北市政府文化局、新北市立鶯歌陶瓷博物館、新北市美術館'], 'comment': '', 'startDate': '2021/10/09', 'endDate': '2021/12/26', 'hitRate': 0})]
# (Background on this error at: https://sqlalche.me/e/14/f405)
